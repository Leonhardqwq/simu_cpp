# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = pd.read_csv("output.csv")['value'].to_numpy()

# %%
idx1 = np.where(x==1)[0]
idx2 = np.where(x==2)[0]

new = (idx1[:,np.newaxis] + np.array([74 +28*i for i in range(4)])).reshape(-1)
size = min(len(new), len(idx2))

diff = new[:size] - idx2[:size]
diff.min(), diff.max()
# Out:
# (0, 0)

# %%
for i in range(len(idx1)):
    print(idx1[i], idx2[i])

# %%
cds = idx1[1:]-idx1[:-1]

# %%
value_counts = pd.Series(cds).value_counts()
value_counts.sort_index(inplace=True)
value_counts.plot(kind='bar')
# Out:
# <Axes: >
