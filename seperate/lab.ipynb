# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
zombie = pd.read_csv('i1-slow-jack.csv')['value'].to_numpy().astype(int)
giga = pd.read_csv('i1-fast-giga.csv')['value'].to_numpy().astype(int)
dlt = giga - zombie

# %%
np.where(dlt==54)
# Out:
# (array([1232, 1233, 1234, 1235, 1236, 1239, 1240, 1241, 1242, 1243, 1244,
#         1245, 1246, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257,
#         1258, 1261, 1262, 1263, 1266, 1267, 1268, 1269, 1270, 1271, 1272,
#         1273, 1274, 1275, 1276, 1308, 1309, 1310, 1311, 1337, 1338, 1339,
#         1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1349, 1350, 1351,
#         1352, 1357, 1358, 1363, 1367, 1368, 1448, 1449, 1452, 1453, 1454,
#         1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1466,
#         1467, 1468, 1469, 1470, 1471, 1476, 1477, 1483, 1484, 1490, 1497,
#         1500, 1501, 1502, 1503, 1509, 1510, 1532, 1533, 1534, 1535, 1536,
#         1537, 1538, 1539, 1540, 1541, 1542], dtype=int64),)

# %%
plt.plot(dlt)
plt.ylim(0,70)
# Out:
# (0.0, 70.0)
