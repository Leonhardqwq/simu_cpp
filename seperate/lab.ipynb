# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
zombie = pd.read_csv('i1-slow-foot.csv')['value'].to_numpy().astype(int)
giga = pd.read_csv('i1-fast-giga.csv')['value'].to_numpy().astype(int)
dlt = giga - zombie

# %%
np.where(dlt==72)
# Out:
# (array([428, 429, 430, 432, 433, 434, 435, 436, 437, 522, 526, 527, 528,
#         529, 595, 596], dtype=int64),)

# %%
plt.plot(dlt)
plt.ylim(0,130)
# Out:
# (0.0, 130.0)

# %%
# 76	62	123	22  
# 68	54	56	18  
# 69	55	54	19  
# 83	69	/	27  
# 68	54	56	18  
# 72	58	55	20
