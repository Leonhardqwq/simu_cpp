# %%
import pandas as pd
import numpy as np

# %%
prob[:600+1].sum()
# Out:
# np.float64(0.0)

# %% [markdown]
# $
# i: 冰时机 \\
# f: 冻结时长(399-599) \\
# L: 出生点到10的距离 \\
# v: 速度参数 \\
# $

# %% [markdown]
# 可啃食时机
# $
# i + f + 700-2 \cdot[i-(\lceil L/v \rceil+1+130)]
# \\
# =962 - i+ f+2\cdot\lceil L/v \rceil
# $
#
# 站稳时机
# $
# \lceil L/v \rceil+1+130
# $

# %%
473+74
# Out:
# 547
